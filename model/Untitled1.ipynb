# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 11367, done.
# remote: Total 11367 (delta 0), reused 0 (delta 0), pack-reused 11367
# Receiving objects: 100% (11367/11367), 11.28 MiB | 22.60 MiB/s, done.
# Resolving deltas: 100% (7847/7847), done.

# %%
# %cd /content/yolov5
# !pip install -U -r requirements.txt
import torch
from IPython.display import Image
# Out:
# /content/yolov5
# ...

# %%
# !nvidia-smi
# Out:
# Thu Mar 17 15:25:45 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/iAmEthanMai/mask-detection-dataset.git
# Out:
# Cloning into 'mask-detection-dataset'...
# remote: Enumerating objects: 3502, done.
# remote: Total 3502 (delta 0), reused 0 (delta 0), pack-reused 3502
# Receiving objects: 100% (3502/3502), 400.63 MiB | 32.17 MiB/s, done.
# Resolving deltas: 100% (881/881), done.
# Checking out files: 100% (2567/2567), done.

# %%
# !python3 /content/yolov5/train.py --batch 1 --epochs 100 --data /content/mask-detection-dataset/data/data.yaml --cfg /content/yolov5/models/yolov5s.yaml --weights '' --device 0
# Out:
# ...
# train: weights=, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/mask-detection-dataset/data/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=1, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-37-g3f634d4 torch 1.11.0+cu102 CUDA:0 (Tesla K80, 11441MiB)
#
# ...
