# %%
# !git clone https://github.com/Mysterious-Harsh/Real_Time_Face_Mask_Detection.git
# !pip install -r Real_Time_Face_Mask_Detection/requirements.txt
# !python Real_Time_Face_Mask_Detection/Main.py
# Out:
# /Users/kishan
# ...
# ERROR: Could not find a version that satisfies the requirement windows-curses (from versions: none)
# ERROR: No matching distribution found for windows-curses
# in project
# 2022-04-21 07:57:31,707 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-21 07:57:31,708 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("loginmaster")
# 2022-04-21 07:57:31,708 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-21 07:57:31,708 INFO sqlalchemy.engine.Engine COMMIT
# 2022-04-21 07:57:31,715 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-21 07:57:31,715 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("loginmaster")
# 2022-04-21 07:57:31,715 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-21 07:57:31,715 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("videomaster")
# 2022-04-21 07:57:31,715 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-21 07:57:31,715 INFO sqlalchemy.engine.Engine COMMIT
# ...
